# %% [markdown]
# # Limpieza de vuelos
#
# Partiendo de los vuelos de salida se hace un analisis de las dimensiones de calidad de datos, se anaden datos nuevos de region y se genera un nuevo dataset limpio de vuelos.

# %% [markdown]
# ## Librerias

# %%
# %load_ext autoreload
# %autoreload 2

from typing import Dict, List, Any
import gc
import re

from unidecode import unidecode
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm

import univariate_utils, multivariate_utils

# %% [markdown]
# ## Constantes

# %%
# Flight file
FLIGHT_FILE = "data/Seguimiento PAX.xlsx"
# Departures sheet
DEPARTURE_SHEET = "Salidas"

# %%
# Name of relevant flight columns
RELEVANT_FLIGHT_COLUMNS = [
    # Categorical
    "Destino",
    "Tipo de vuelo",
    "Sala",
    "Muelle",
    "FECHA DIA",
    "AEROLÍNEA",
    "Tipo aerolínea",
    # Date
    "STD",
    # Numerical
    "Pasajeros saliendo",
    "Hora entera",
    "Semana",
    "Mes",
    "Día",
    "Año"
]

# %%
FLIGHTS_SAVE_FILE = "data/clean_flights.parquet"

# %% [markdown]
# ## Utils

# %%
def load_flight_data() -> pd.DataFrame:
    """Reads flights departures"""
    return pd.read_excel(
        FLIGHT_FILE,
        sheet_name=DEPARTURE_SHEET
    )

# %%
def safe_standardize_text(text: str) -> str:
    """Standardizes text to lower and deaccented form"""
    try:
        try:
            is_nan = np.isnan(text)
        except:
            is_nan = text is None
        if is_nan:
            return np.nan
        else:
            return re.sub(
                r"\s+",
                " ",
                re.sub(
                    r'\W+',
                    " ",
                    unidecode(str(text)).lower().strip()
                )
            ).strip()
    except:
        return np.nan

# %%
def safe_standardize_int(value: Any) -> int:
    """Safely converts value to int"""
    try:
        return np.int64(value)
    except:
        return np.nan

# %%
def standardize_categories(df: pd.DataFrame, col: str, fixing_map: Dict[Any, Any]) -> None:
    """Standardizes dataframe column categories based on a fix map"""
    df[col] = df[col].apply(
        lambda value: fixing_map[value]
        if value in fixing_map.keys()
        else value
    )

# %%
def safe_standardize_date(date_val: Any) -> pd.Series:
    """Converts a column into a date column"""
    try:
        return date_val.date()
    except:
        return pd.to_datetime(date_val).date()

# %%
def standardize_flights(df: pd.DataFrame) -> pd.DataFrame:
    """Selects relevant columns and transform categories into standard values"""
    df_flight_data = df_flights[RELEVANT_FLIGHT_COLUMNS].copy(deep=True)
    
    df_flight_data["Destino"] = df_flight_data["Destino"].apply(
        safe_standardize_text
    )
    df_flight_data["Tipo de vuelo"] = df_flight_data["Tipo de vuelo"].apply(
        safe_standardize_text
    )
    df_flight_data["Sala"] = df_flight_data["Sala"].apply(
        safe_standardize_text
    )
    df_flight_data["Muelle"] = df_flight_data["Muelle"].apply(
        safe_standardize_text
    )
    df_flight_data["FECHA DIA"] = df_flight_data["FECHA DIA"].apply(
        safe_standardize_text
    )
    df_flight_data["AEROLÍNEA"] = df_flight_data["AEROLÍNEA"].apply(
        safe_standardize_text
    )
    df_flight_data["Tipo aerolínea"] = df_flight_data["Tipo aerolínea"].apply(
        safe_standardize_text
    )
    df_flight_data["Pasajeros saliendo"] = df_flight_data["Pasajeros saliendo"].apply(
        safe_standardize_int
    )
    df_flight_data["Hora entera"] = df_flight_data["Hora entera"].apply(
        safe_standardize_int
    )  
    df_flight_data["Semana"] = df_flight_data["Semana"].apply(
        safe_standardize_int
    )
    df_flight_data["Mes"] = df_flight_data["Mes"].apply(
        safe_standardize_int
    )
    df_flight_data["Día"] = df_flight_data["Día"].apply(
        safe_standardize_int
    )
    df_flight_data["Año"] = df_flight_data["Año"].apply(
        safe_standardize_int
    )
    df_flight_data["STD_date"] = df_flight_data["STD"].apply(safe_standardize_date)

    return df_flight_data

# %%
def clip_data_by_iqr(df, col, strategy, iqr_multiplier):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    bottom_limit = Q1 - iqr_multiplier * IQR
    top_limit = Q3 + iqr_multiplier * IQR
    
    is_low = df[col] <= bottom_limit
    is_high = df[col] >= top_limit
    
    if strategy == "bottom":
        df.loc[is_low, col] = bottom_limit
    if strategy == "top":
        df.loc[is_high, col] = top_limit
    else:
        df.loc[is_low, col] = bottom_limit
        df.loc[is_high, col] = top_limit

# %% [markdown]
# ## Ejecucion

# %% [markdown]
# ### Carga de vuelos
# Se leen los vuelos de salida.

# %%
df_flights = load_flight_data()

# %% [markdown]
# ### Seleccion de columnas relevantes de vuelos (Dimension de relevancia)
#
# Acorde a lo revisado con negocio y en el equipo se toma solo una serie de columnas relevantes para el analisis y la regresion. Este dataframe contiene un numero de nulos extremadamente bajo, pudiendose eliminar las filas con esta condicion (dimension de completitud a nivel de atributo).

# %%
df_flights.columns
# Out:
# Index(['Aerolinea', 'Vuelo de salida', 'IATA CODE', 'Destino',
#        'Pasajeros saliendo', 'STD', 'Posicion de salida', 'Tipo V',
#        'Tipo de vuelo', 'Sala', 'Sala Antigua', 'Tipo de aeronave', 'ETD',
#        'ATD', 'Ofchocks', 'Max pasajeros', 'Calificador de salida',
#        'Matricula', 'Fecha de salida', 'Muelle', 'Hora', 'Hora entera', 'OPER',
#        'FECHA DIA', 'AEROLÍNEA', 'Hora compra', 'Tipo aerolínea', 'Semana',
#        'Mes', 'Día', 'Año'],
#       dtype='object')

# %%
df_flights[RELEVANT_FLIGHT_COLUMNS].head(5)
# Out:
#         Destino Tipo de vuelo  Sala          Muelle FECHA DIA  \
# 0     Cartagena     Doméstico   D11  D Nacional sur    martes
# 1        Cúcuta     Doméstico    D4  D Nacional sur    martes
# 2       Pereira     Doméstico  D15A  D Nacional sur    martes
# 3     Cartagena     Doméstico  D15B  D Nacional sur    martes
# 4  Barranquilla     Doméstico    D1  D Nacional sur    martes
#
#             AEROLÍNEA Tipo aerolínea                  STD  Pasajeros saliendo  \
# 0         AVIANCA S.A         Legacy  2020-09-01 08:05:00                 133
# 1         AVIANCA S.A         Legacy  2020-09-01 09:00:00                  88
# 2      EASYFLY S.A.S.       Regional  2020-09-01 07:05:00                  20
# 3  VIVA COLOMBIA S.A.       Low Cost  2020-09-01 09:25:00                 131
# 4         AVIANCA S.A         Legacy  2020-09-01 06:11:00                 127
#
#    Hora entera  Semana  Mes  Día   Año
# 0            8      36    9    1  2020
# 1            9      36    9    1  2020
# 2            7      36    9    1  2020
# 3            9      36    9    1  2020
# 4            6      36    9    1  2020

# %%
df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344146 entries, 0 to 344145
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Aerolinea              344146 non-null  object
#  1   Vuelo de salida        344146 non-null  object
#  2   IATA CODE              344146 non-null  object
#  3   Destino                344146 non-null  object
#  4   Pasajeros saliendo     344146 non-null  int64
#  5   STD                    344146 non-null  object
#  6   Posicion de salida     344072 non-null  object
#  7   Tipo V                 344146 non-null  object
#  8   Tipo de vuelo          344146 non-null  object
#  9   Sala                   344146 non-null  object
#  10  Sala Antigua           344146 non-null  object
#  11  Tipo de aeronave       344146 non-null  object
#  12  ETD                    344040 non-null  object
#  13  ATD                    343844 non-null  object
#  14  Ofchocks               344146 non-null  datetime64[ns]
#  15  Max pasajeros          343745 non-null  object
#  16  Calificador de salida  344146 non-null  object
#  17  Matricula              344144 non-null  object
#  18  Fecha de salida        344146 non-null  datetime64[ns]
#  19  Muelle                 344146 non-null  object
#  20  Hora                   344146 non-null  datetime64[ns]
#  21  Hora entera            344146 non-null  int64
#  22  OPER                   344146 non-null  object
#  23  FECHA DIA              344146 non-null  object
#  24  AEROLÍNEA              344145 non-null  object
#  25  Hora compra            344146 non-null  int64
#  26  Tipo aerolínea         344145 non-null  object
#  27  Semana                 344146 non-null  int64
#  28  Mes                    344146 non-null  int64
#  29  Día                    344146 non-null  int64
#  30  Año                    344146 non-null  int64
# dtypes: datetime64[ns](3), int64(7), object(21)
# memory usage: 81.4+ MB

# %%
df_flights[RELEVANT_FLIGHT_COLUMNS].isnull().sum()/len(df_flights)
# Out:
# Destino               0.000000
# Tipo de vuelo         0.000000
# Sala                  0.000000
# Muelle                0.000000
# FECHA DIA             0.000000
# AEROLÍNEA             0.000003
# Tipo aerolínea        0.000003
# STD                   0.000000
# Pasajeros saliendo    0.000000
# Hora entera           0.000000
# Semana                0.000000
# Mes                   0.000000
# Día                   0.000000
# Año                   0.000000
# dtype: float64

# %% [markdown]
# ### Estandarizacion de datos de vuelo
#
# Se aplica un proceso similar al de ventas, en donde se normaliza el texto y se asegura el tipo de valor en las variables numericas.

# %%
df_clean_flights = standardize_flights(df_flights)

# %%
df_clean_flights.isnull().sum()/len(df_flights)
# Out:
# Destino               0.000000
# Tipo de vuelo         0.000000
# Sala                  0.000000
# Muelle                0.000000
# FECHA DIA             0.000000
# AEROLÍNEA             0.000003
# Tipo aerolínea        0.000003
# STD                   0.000000
# Pasajeros saliendo    0.000000
# Hora entera           0.000000
# Semana                0.000000
# Mes                   0.000000
# Día                   0.000000
# Año                   0.000000
# STD_date              0.000000
# dtype: float64

# %% [markdown]
# #### Eliminacion de filas nulas en AEROLÍNEA y Tipo aerolínea (Dimension de completitud a nivel de atributo)
# Como estas columnas tienen un numero de nulos menor al 1%, pero son necesarias para la regresion, se eliminan las pocas filas con esta condicion.

# %%
df_clean_flights.dropna(
    subset=["Tipo aerolínea", "AEROLÍNEA"],
    inplace=True
)

# %% [markdown]
# #### Aseguramiento de tipos de dato entero
# Dependiendo de la version de pandas, el metodo de estandarizacion de datos enteros puede entender la columna como float64, y es necesario hacer la correccion.

# %%
for col in ["Pasajeros saliendo", "Hora entera", "Semana", "Mes", "Día", "Año"]:
    df_clean_flights[col] = df_clean_flights[col].astype(int)

# %% [markdown]
# ### Dimensiones de calidad de variables numericas
#
# Se evaluan posibles anomalias y se establecen correciones:
# - En la dimension de conformidad se tienen vuelos con pasajeros saliendo mas extremos de lo "normal", por encima de 193, asi que se hace clipping. Tambien hay vuelos de 0 pasajeros, pero esto requiere investigar con negocio.
# - Las demas variables numericas presentan rangos de valores aceptables.

# %%
univariate_utils.make_not_graphic_analysis(df_clean_flights)
# Out:
# ----- dataset info -----
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344145 entries, 0 to 344145
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Destino             344145 non-null  object
#  1   Tipo de vuelo       344145 non-null  object
#  2   Sala                344145 non-null  object
#  3   Muelle              344145 non-null  object
#  4   FECHA DIA           344145 non-null  object
#  5   AEROLÍNEA           344145 non-null  object
#  6   Tipo aerolínea      344145 non-null  object
#  7   STD                 344145 non-null  object
#  8   Pasajeros saliendo  344145 non-null  int64
#  9   Hora entera         344145 non-null  int64
#  10  Semana              344145 non-null  int64
#  11  Mes                 344145 non-null  int64
#  12  Día                 344145 non-null  int64
#  13  Año                 344145 non-null  int64
#  14  STD_date            344145 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 42.0+ MB
# ----- null percentage -----
# Destino               0.0
# Tipo de vuelo         0.0
# Sala                  0.0
# Muelle                0.0
# FECHA DIA             0.0
# AEROLÍNEA             0.0
# Tipo aerolínea        0.0
# STD                   0.0
# Pasajeros saliendo    0.0
# Hora entera           0.0
# Semana                0.0
# Mes                   0.0
# Día                   0.0
# Año                   0.0
# STD_date              0.0
# dtype: float64
# ----- Object column statistics -----
#          Destino Tipo de vuelo    Sala          Muelle FECHA DIA    AEROLÍNEA  \
# count     344145        344145  344145          344145    344145       344145
# unique       122             2      75               5         7           52
# top     medellin     domestico      d3  d nacional sur   viernes  avianca s a
# freq       42361        254283   10244          158427     50841       167018
#
#        Tipo aerolínea                  STD    STD_date
# count          344145               344145      344145
# unique              5               244741        1099
# top            legacy  2021-07-20 13:30:00  2023-01-02
# freq           256334                   12         426
# ----- Number column statistics -----
#        Pasajeros saliendo    Hora entera         Semana            Mes  \
# count       344145.000000  344145.000000  344145.000000  344145.000000
# mean           126.469395      12.568211      26.080237       6.413038
# std             52.932171       5.513929      14.916871       3.411267
# min              0.000000       0.000000       1.000000       1.000000
# 5%              37.000000       5.000000       3.000000       1.000000
# 25%             94.000000       8.000000      13.000000       4.000000
# 50%            133.000000      13.000000      26.000000       6.000000
# 75%            161.000000      17.000000      38.000000       9.000000
# 95%            193.000000      22.000000      50.000000      12.000000
# max            401.000000      23.000000      53.000000      12.000000
#
#                  Día            Año
# count  344145.000000  344145.000000
# mean       15.710012    2021.905862
# std         8.818160       0.855722
# min         1.000000    2020.000000
# 5%          2.000000    2021.000000
# 25%         8.000000    2021.000000
# 50%        16.000000    2022.000000
# 75%        23.000000    2023.000000
# 95%        29.000000    2023.000000
# max        31.000000    2023.000000
# ----- First five rows -----
#         Destino Tipo de vuelo  Sala          Muelle FECHA DIA  \
# 0     cartagena     domestico   d11  d nacional sur    martes
# 1        cucuta     domestico    d4  d nacional sur    martes
# 2       pereira     domestico  d15a  d nacional sur    martes
# 3     cartagena     domestico  d15b  d nacional sur    martes
# 4  barranquilla     domestico    d1  d nacional sur    martes
#
#            AEROLÍNEA Tipo aerolínea                  STD  Pasajeros saliendo  \
# 0        avianca s a         legacy  2020-09-01 08:05:00                 133
# 1        avianca s a         legacy  2020-09-01 09:00:00                  88
# 2      easyfly s a s       regional  2020-09-01 07:05:00                  20
# 3  viva colombia s a       low cost  2020-09-01 09:25:00                 131
# 4        avianca s a         legacy  2020-09-01 06:11:00                 127
#
#    Hora entera  Semana  Mes  Día   Año    STD_date
# 0            8      36    9    1  2020  2020-09-01
# 1            9      36    9    1  2020  2020-09-01
# 2            7      36    9    1  2020  2020-09-01
# 3            9      36    9    1  2020  2020-09-01
# 4            6      36    9    1  2020  2020-09-01

# %%
univariate_utils.plot_column_distribution(
        df_clean_flights,
        "Pasajeros saliendo",
        (15,5),
        60
    )

# %%
clip_data_by_iqr(df_clean_flights, "Pasajeros saliendo", "top", 1.5)

# %% [markdown]
# #### Estandarizacion de destino (Dimension de conformidad a nivel de atributo)
# Se miran destinos que sean la misma ciudad (duplicados aproximados) y se reemplazan por la notacion mas comun.

# %%
sorted(
    df_clean_flights["Destino"].unique()
)
# Out:
# ['abu dabi',
#  'aguachica',
#  'aguadilla',
#  'alejandria',
#  'amsterdam',
#  'antofagasta',
#  'apartado',
#  'arauca',
#  'armenia',
#  'aruba',
#  'asuncion',
#  'atlanta',
#  'bahamas',
#  'balboa',
#  'barcelona',
#  'barrancabermeja',
#  'barranquilla',
#  'belo horizonte brasil',
#  'boston',
#  'bridgetown barbados',
#  'brownsville',
#  'bucaramanga',
#  'buenaventura',
#  'buenos aires',
#  'buenos aires 2',
#  'cali',
#  'cancun',
#  'caracas',
#  'cartagena',
#  'casablanca',
#  'ciud panama',
#  'cochabamba',
#  'corozal',
#  'cucuta',
#  'curacao willemstad',
#  'dallas',
#  'dubai',
#  'el yopal',
#  'estambul',
#  'florencia',
#  'fort lauderdale',
#  'frankfurt',
#  'guadalajara',
#  'guatemala',
#  'guayaquil',
#  'habana',
#  'harlingen',
#  'houston',
#  'ibague',
#  'ipiales',
#  'la macarena',
#  'la paz',
#  'la romana rep dominicana',
#  'leticia',
#  'lima',
#  'lisboa',
#  'londres',
#  'los angeles',
#  'madrid',
#  'manaos',
#  'manizales',
#  'maturin',
#  'medellin',
#  'mendoza argentina',
#  'merida mexico',
#  'mexico',
#  'miami',
#  'mitu',
#  'monteria',
#  'monterrey',
#  'montevideo',
#  'montreal',
#  'neiva',
#  'nueva york',
#  'orlando',
#  'paramaribo',
#  'paris',
#  'pasto',
#  'pereira',
#  'phoenix eeuu',
#  'phoenix mesa arizona',
#  'piarco',
#  'pitalito',
#  'popayan',
#  'porto alegre',
#  'puerto asis',
#  'puerto carreno',
#  'puerto gaitan',
#  'puerto inirida',
#  'puerto leguizamo',
#  'punta cana',
#  'quibdo',
#  'quito',
#  'rio de janeiro',
#  'riohacha',
#  'san andres',
#  'san antonio texas',
#  'san jose',
#  'san jose del guaviare',
#  'san juan puerto rico',
#  'san salvador',
#  'san vicente del caguan',
#  'santa clara cuba',
#  'santa cruz de la sierra',
#  'santa marta',
#  'santiago',
#  'santiago de los caballeros',
#  'santo domingo',
#  'santo domingo la isabela',
#  'sao carlos',
#  'sao pablo',
#  'saravena',
#  'tame',
#  'tolu',
#  'toronto',
#  'trujillo peru',
#  'tumaco',
#  'valledupar',
#  'villa garzon',
#  'villavicencio',
#  'washington',
#  'yuma arizona']

# %%
fix_destino = {
    "buenos aires 2": "buenos aires",
    "phoenix eeuu": "phoenix arizona",
    "phoenix mesa arizona": "phoenix arizona",
}

# %%
standardize_categories(df_clean_flights, "Destino", fix_destino)

# %% [markdown]
# #### Estandarizacion de Muelle (Dimension de conformidad a nivel de atributo)
# En los muelles se tienen muelles nacionales adicionales a los de las ventas, asi que se genera un formato similar al de las ventas para poder cruzar datos.

# %%
sorted(
    df_clean_flights["Muelle"].unique()
)
# Out:
# ['a internacional oriente',
#  'b internacional occidente',
#  'c nacional norte',
#  'd nacional sur',
#  'tpa']

# %%
fix_muelle = {
    "a internacional oriente": "muelle internacional oriente",
    "b internacional occidente": "muelle internacional occidente",
    "c nacional norte": "muelle nacional norte",
    "d nacional sur": "muelle nacional sur"
}

# %%
standardize_categories(df_clean_flights, "Muelle", fix_muelle)

# %%
sorted(
    df_clean_flights["Muelle"].unique()
)
# Out:
# ['muelle internacional occidente',
#  'muelle internacional oriente',
#  'muelle nacional norte',
#  'muelle nacional sur',
#  'tpa']

# %% [markdown]
# ### Agrupacion de vuelos en formato horario
#
# Se toman las columnas categoricas relevantes y las de fecha y hora para generar informacion de numero de pasajeros agrupada por estos valores. Pero primero se eliminan duplicados por estas columnas.

# %%
df_clean_flights.drop_duplicates(
    subset=[
        "Destino",
        "Tipo de vuelo",
        "Sala",
        "Muelle",
        "AEROLÍNEA",
        "Tipo aerolínea",
        "STD_date",
        "Hora entera"
    ],
    inplace=True
)

# %%
df_hourly_flights = df_clean_flights.groupby([
    "Destino",
    "Tipo de vuelo",
    "Sala",
    "Muelle",
    "AEROLÍNEA",
    "Tipo aerolínea",
    "STD_date",
    "Hora entera"
]).agg({
    "FECHA DIA": "min",
    "Pasajeros saliendo": "sum",
    "Semana": "min",
    "Mes": "min",
    "Día": "min",
    "Año": "min",
    "STD": "min"
}).reset_index(drop=False)

# %%
df_hourly_flights = df_hourly_flights[RELEVANT_FLIGHT_COLUMNS + ["STD_date"]].copy(deep=True)

# %% [markdown]
# #### Revision de valores anomalos en "Pasajeros saliendo" generados por la agrupacion horaria
#
# Por la dimension de conformidad se hace clipping de estos valores extremos a 1.5 * IQR.

# %%
univariate_utils.make_not_graphic_analysis(df_hourly_flights)
# Out:
# ----- dataset info -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343905 entries, 0 to 343904
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Destino             343905 non-null  object
#  1   Tipo de vuelo       343905 non-null  object
#  2   Sala                343905 non-null  object
#  3   Muelle              343905 non-null  object
#  4   FECHA DIA           343905 non-null  object
#  5   AEROLÍNEA           343905 non-null  object
#  6   Tipo aerolínea      343905 non-null  object
#  7   STD                 343905 non-null  object
#  8   Pasajeros saliendo  343905 non-null  float64
#  9   Hora entera         343905 non-null  int64
#  10  Semana              343905 non-null  int64
#  11  Mes                 343905 non-null  int64
#  12  Día                 343905 non-null  int64
#  13  Año                 343905 non-null  int64
#  14  STD_date            343905 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 39.4+ MB
# ----- null percentage -----
# Destino               0.0
# Tipo de vuelo         0.0
# Sala                  0.0
# Muelle                0.0
# FECHA DIA             0.0
# AEROLÍNEA             0.0
# Tipo aerolínea        0.0
# STD                   0.0
# Pasajeros saliendo    0.0
# Hora entera           0.0
# Semana                0.0
# Mes                   0.0
# Día                   0.0
# Año                   0.0
# STD_date              0.0
# dtype: float64
# ----- Object column statistics -----
#          Destino Tipo de vuelo    Sala               Muelle FECHA DIA  \
# count     343905        343905  343905               343905    343905
# unique       120             2      75                    5         7
# top     medellin     domestico      d3  muelle nacional sur   viernes
# freq       42294        254053   10242               158393     50803
#
#           AEROLÍNEA Tipo aerolínea                  STD    STD_date
# count        343905         343905               343905      343905
# unique           52              5               244669        1099
# top     avianca s a         legacy  2021-07-20 13:30:00  2023-01-02
# freq         166992         256256                   12         424
# ----- Number column statistics -----
#        Pasajeros saliendo    Hora entera         Semana            Mes  \
# count       343905.000000  343905.000000  343905.000000  343905.000000
# mean           125.989849      12.569631      26.081302       6.413254
# std             51.192864       5.513520      14.917146       3.411308
# min              0.000000       0.000000       1.000000       1.000000
# 5%              38.000000       5.000000       3.000000       1.000000
# 25%             94.000000       8.000000      13.000000       4.000000
# 50%            133.000000      13.000000      26.000000       6.000000
# 75%            161.000000      17.000000      38.000000       9.000000
# 95%            193.000000      22.000000      50.000000      12.000000
# max            261.500000      23.000000      53.000000      12.000000
#
#                  Día            Año
# count  343905.000000  343905.000000
# mean       15.710071    2021.905616
# std         8.818473       0.855773
# min         1.000000    2020.000000
# 5%          2.000000    2021.000000
# 25%         8.000000    2021.000000
# 50%        16.000000    2022.000000
# 75%        23.000000    2023.000000
# 95%        29.000000    2023.000000
# max        31.000000    2023.000000
# ----- First five rows -----
#      Destino  Tipo de vuelo  Sala                        Muelle  FECHA DIA  \
# 0   abu dabi  internacional   a7a  muelle internacional oriente  miercoles
# 1   abu dabi  internacional  rori  muelle internacional oriente    domingo
# 2  aguachica      domestico     1                           tpa     jueves
# 3  aguachica      domestico     1                           tpa     jueves
# 4  aguachica      domestico     1                           tpa     jueves
#
#            AEROLÍNEA Tipo aerolínea                  STD  Pasajeros saliendo  \
# 0  aerosupport s a s         legacy  2020-09-01 22:40:00                15.0
# 1  aerosupport s a s         legacy  2020-09-20 07:05:00                50.0
# 2             satena       regional  2023-02-16 06:32:00                39.0
# 3             satena       regional  2023-02-23 06:32:00                41.0
# 4             satena       regional  2023-03-02 06:32:00                42.0
#
#    Hora entera  Semana  Mes  Día   Año    STD_date
# 0            0      36    9    2  2020  2020-09-01
# 1            9      38    9   20  2020  2020-09-20
# 2            6       7    2   16  2023  2023-02-16
# 3            6       8    2   23  2023  2023-02-23
# 4            6       9    3    2  2023  2023-03-02

# %%
univariate_utils.plot_column_distribution(
        df_hourly_flights,
        "Pasajeros saliendo",
        (15,5),
        60
    )

# %%
clip_data_by_iqr(df_hourly_flights, "Pasajeros saliendo", "top", 1.5)

# %%
univariate_utils.plot_column_distribution(
        df_hourly_flights,
        "Pasajeros saliendo",
        (15,5),
        60
    )

# %% [markdown]
# ### Conteo de pasajeros por Muelle, fecha y hora
# Se agrupa por muelle, fecha y hora para calcular el trafico total del muelle a determinada fecha y hora.

# %%
df_hourly_flights["Pasajeros por Muelle y Hora"] = (
    df_hourly_flights.groupby(["Muelle", "STD", "Hora entera"])["Pasajeros saliendo"].transform("sum")
)

# %% [markdown]
# ### Calculo de porcentaje de pasajeros de un muelle que salen a un vuelo en cierta fecha y hora
#
# Se toma el numero de pasajeros en el muelle en ese momento y se calcula el porcentaje de pasajeros que van en un vuelo en ese mismo momento respecto de los del muelle.

# %%
df_hourly_flights["Porcentaje pasajeros vuelo"] = (
    df_hourly_flights["Pasajeros saliendo"] /
    df_hourly_flights["Pasajeros por Muelle y Hora"]
)

# %%
df_hourly_flights["Porcentaje pasajeros vuelo"] = \
    df_hourly_flights["Porcentaje pasajeros vuelo"].fillna(0.0)

# %%
df_hourly_flights["Porcentaje pasajeros vuelo"].describe()
# Out:
# count    343905.000000
# mean          0.903130
# std           0.215415
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: Porcentaje pasajeros vuelo, dtype: float64

# %% [markdown]
# ### Guardado del dataframe limpio

# %%
df_hourly_flights["STD"] = pd.to_datetime(df_hourly_flights["STD"])

# %%
df_hourly_flights.to_parquet(FLIGHTS_SAVE_FILE, index=False)
