# %% [markdown]
# # Vuelos y ventas a marca
#
# Este notebook une informacion de vuelos y ventas y genera un dataframe por marca seleccionada.

# %% [markdown]
# ## Librerias

# %%
# %load_ext autoreload
# %autoreload 2

from typing import Dict, List, Any
import gc
import re

from unidecode import unidecode
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm

import univariate_utils, multivariate_utils

# %% [markdown]
# ## Constantes

# %%
CLEAN_FLIGHTS_FILE = "data/clean_flights.parquet"

# %%
CLEAN_SALES_FILE = "data/clean_sales.parquet"

# %%
MUELLE_FILE = "data/muelle.parquet"

# %% [markdown]
# ## Utils

# %%
def clip_data_by_iqr(df, col, strategy, iqr_multiplier):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    bottom_limit = Q1 - iqr_multiplier * IQR
    top_limit = Q3 + iqr_multiplier * IQR
    
    is_low = df[col] <= bottom_limit
    is_high = df[col] >= top_limit
    
    if strategy == "bottom":
        df.loc[is_low, col] = bottom_limit
    if strategy == "top":
        df.loc[is_high, col] = top_limit
    else:
        df.loc[is_low, col] = bottom_limit
        df.loc[is_high, col] = top_limit

# %% [markdown]
# ## Ejecucion

# %% [markdown]
# ### Carga de dataframes

# %%
df_hourly_flights = pd.read_parquet(CLEAN_FLIGHTS_FILE)

# %%
df_sales = pd.read_parquet(CLEAN_SALES_FILE)

# %% [markdown]
# ### Agrupacion de ventas por hora y marca
#
# Se hace un corte de las ventas por iqr para evitar outliers.

# %%
hourly_sales_per_marca = {}
for marca, df_marca_sales in df_sales.groupby("marca"):
    hourly_sales_per_marca[marca] = df_marca_sales.groupby(
        ["muelle_venta", "fecha_venta", "hora_venta"]
    ).agg({
        "transacciones_venta": "sum",
        "valor_venta": "sum"
    }).reset_index(drop=False)

# %%
for marca, df_marca_sales in df_sales.groupby("marca"):
    print(marca)
    clip_data_by_iqr(df_marca_sales, "valor_venta", "top", 1.5)
    univariate_utils.plot_column_distribution(
            df_marca_sales,
            "valor_venta",
            (15,5),
            60
        )
# Out:
# marca 1
# marca 10
# marca 2
# marca 3
# marca 5
# marca 6
# marca 7
# marca 9

# %% [markdown]
# ### Integracion de datos con datos de ventas

# %% [markdown]
# #### Seleccion de muelle (Dimension de relevancia)
# El unico muelle en comun es muelle internacional oriente, asi que se toman los datos de este muelle y se hace una union entre vuelos y ventas agrupadas por hora con la condicion de que las ventas representan las ventas en las dos horas anteriores al vuelo.

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    print(
        marca,
        df_marca_sales["muelle_venta"].unique().tolist()
    )
# Out:
# marca 1 ['muelle internacional oriente']
# marca 10 ['muelle internacional oriente']
# marca 2 ['muelle internacional oriente']
# marca 3 ['muelle internacional centro', 'muelle internacional oriente']
# marca 5 ['muelle internacional oriente']
# marca 6 ['muelle internacional oriente']
# marca 7 ['muelle internacional oriente']
# marca 9 ['muelle internacional oriente']

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    df_marca_sales = df_marca_sales[
        df_marca_sales["muelle_venta"] == "muelle internacional oriente"
    ].copy(deep=True)

# %%
df_hourly_flights = df_hourly_flights[
    df_hourly_flights["Muelle"] == "muelle internacional oriente"
]

# %% [markdown]
# #### Merge de dataframes
# Se ignora la hora para poder operar la diferencia de 2 horas. Por otro lado se eliminan las filas con nulos en menos del 7% de las filas (aunque se considera eliminar la marca 10 por su alto numero de nulos encima de 20%).

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    hourly_sales_per_marca[marca] = df_hourly_flights.merge(
        df_marca_sales,
        left_on=["Muelle", "STD_date"],
        right_on=["muelle_venta", "fecha_venta"],
        how="left"
    )

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    print(marca)
    df_marca_sales.drop(
        columns=[
            "muelle_venta"
        ],
        inplace=True
    )
    print(df_marca_sales.isnull().sum()/len(df_marca_sales))
# Out:
# marca 1
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.020226
# hora_venta                     0.020226
# transacciones_venta            0.020226
# valor_venta                    0.020226
# dtype: float64
# marca 10
# Destino                        0.00000
# Tipo de vuelo                  0.00000
# Sala                           0.00000
# Muelle                         0.00000
# FECHA DIA                      0.00000
# AEROLÍNEA                      0.00000
# Tipo aerolínea                 0.00000
# STD                            0.00000
# Pasajeros saliendo             0.00000
# Hora entera                    0.00000
# Semana                         0.00000
# Mes                            0.00000
# Día                            0.00000
# Año                            0.00000
# STD_date                       0.00000
# Pasajeros por Muelle y Hora    0.00000
# Porcentaje pasajeros vuelo     0.00000
# fecha_venta                    0.21179
# hora_venta                     0.21179
# transacciones_venta            0.21179
# valor_venta                    0.21179
# dtype: float64
# marca 2
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.021556
# hora_venta                     0.021556
# transacciones_venta            0.021556
# valor_venta                    0.021556
# dtype: float64
# marca 3
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.024507
# hora_venta                     0.024507
# transacciones_venta            0.024507
# valor_venta                    0.024507
# dtype: float64
# marca 5
# Destino                        0.00000
# Tipo de vuelo                  0.00000
# Sala                           0.00000
# Muelle                         0.00000
# FECHA DIA                      0.00000
# AEROLÍNEA                      0.00000
# Tipo aerolínea                 0.00000
# STD                            0.00000
# Pasajeros saliendo             0.00000
# Hora entera                    0.00000
# Semana                         0.00000
# Mes                            0.00000
# Día                            0.00000
# Año                            0.00000
# STD_date                       0.00000
# Pasajeros por Muelle y Hora    0.00000
# Porcentaje pasajeros vuelo     0.00000
# fecha_venta                    0.04414
# hora_venta                     0.04414
# transacciones_venta            0.04414
# valor_venta                    0.04414
# dtype: float64
# marca 6
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.030425
# hora_venta                     0.030425
# transacciones_venta            0.030425
# valor_venta                    0.030425
# dtype: float64
# marca 7
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.024417
# hora_venta                     0.024417
# transacciones_venta            0.024417
# valor_venta                    0.024417
# dtype: float64
# marca 9
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.021923
# hora_venta                     0.021923
# transacciones_venta            0.021923
# valor_venta                    0.021923
# dtype: float64

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    hourly_sales_per_marca[marca] = df_marca_sales[
        ~df_marca_sales["hora_venta"].isnull()
    ].copy(deep=True)
    print(df_marca_sales.isnull().sum()/len(df_marca_sales))
# Out:
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.020226
# hora_venta                     0.020226
# transacciones_venta            0.020226
# valor_venta                    0.020226
# dtype: float64
# Destino                        0.00000
# Tipo de vuelo                  0.00000
# Sala                           0.00000
# Muelle                         0.00000
# FECHA DIA                      0.00000
# AEROLÍNEA                      0.00000
# Tipo aerolínea                 0.00000
# STD                            0.00000
# Pasajeros saliendo             0.00000
# Hora entera                    0.00000
# Semana                         0.00000
# Mes                            0.00000
# Día                            0.00000
# Año                            0.00000
# STD_date                       0.00000
# Pasajeros por Muelle y Hora    0.00000
# Porcentaje pasajeros vuelo     0.00000
# fecha_venta                    0.21179
# hora_venta                     0.21179
# transacciones_venta            0.21179
# valor_venta                    0.21179
# dtype: float64
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.021556
# hora_venta                     0.021556
# transacciones_venta            0.021556
# valor_venta                    0.021556
# dtype: float64
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.024507
# hora_venta                     0.024507
# transacciones_venta            0.024507
# valor_venta                    0.024507
# dtype: float64
# Destino                        0.00000
# Tipo de vuelo                  0.00000
# Sala                           0.00000
# Muelle                         0.00000
# FECHA DIA                      0.00000
# AEROLÍNEA                      0.00000
# Tipo aerolínea                 0.00000
# STD                            0.00000
# Pasajeros saliendo             0.00000
# Hora entera                    0.00000
# Semana                         0.00000
# Mes                            0.00000
# Día                            0.00000
# Año                            0.00000
# STD_date                       0.00000
# Pasajeros por Muelle y Hora    0.00000
# Porcentaje pasajeros vuelo     0.00000
# fecha_venta                    0.04414
# hora_venta                     0.04414
# transacciones_venta            0.04414
# valor_venta                    0.04414
# dtype: float64
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.030425
# hora_venta                     0.030425
# transacciones_venta            0.030425
# valor_venta                    0.030425
# dtype: float64
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.024417
# hora_venta                     0.024417
# transacciones_venta            0.024417
# valor_venta                    0.024417
# dtype: float64
# Destino                        0.000000
# Tipo de vuelo                  0.000000
# Sala                           0.000000
# Muelle                         0.000000
# FECHA DIA                      0.000000
# AEROLÍNEA                      0.000000
# Tipo aerolínea                 0.000000
# STD                            0.000000
# Pasajeros saliendo             0.000000
# Hora entera                    0.000000
# Semana                         0.000000
# Mes                            0.000000
# Día                            0.000000
# Año                            0.000000
# STD_date                       0.000000
# Pasajeros por Muelle y Hora    0.000000
# Porcentaje pasajeros vuelo     0.000000
# fecha_venta                    0.021923
# hora_venta                     0.021923
# transacciones_venta            0.021923
# valor_venta                    0.021923
# dtype: float64

# %% [markdown]
# #### Reintegrando timestamp de venta (dimension de conformidad)
#
# Este formato es necesario para poder encontrar las horas de venta anteriores al vuelo.

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    df_marca_sales["timestamp_venta"] = (
        pd.to_datetime(df_marca_sales["fecha_venta"])
        + pd.to_timedelta(
            df_marca_sales["hora_venta"],
            unit="hours"
        )
    )

# %% [markdown]
# #### Filtrado de ventas en las dos horas anteriores

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():

    df_marca_sales["STD"] = pd.to_datetime(df_marca_sales["STD"])
    df_marca_sales["time_difference"] = (
        (df_marca_sales["STD"] - df_marca_sales["timestamp_venta"]).dt.seconds
        / float(3600)
    )
    is_sale_before_flight = (
        (df_marca_sales["time_difference"] <= 2.0)
        & (df_marca_sales["STD"] >= df_marca_sales["timestamp_venta"])
    )
    hourly_sales_per_marca[marca] = df_marca_sales[is_sale_before_flight].copy(deep=True)

# %% [markdown]
# #### Re agrupacion por hora y vuelo
#
# Se evalua que no se generen valores anomalos al agrupar (dimension de conformidad a nivel de atributo)

# %%
hourly_sales_per_marca["marca 1"]
# Out:
#               Destino  Tipo de vuelo  Sala                        Muelle  \
# 52          amsterdam  internacional    a1  muelle internacional oriente
# 53          amsterdam  internacional    a1  muelle internacional oriente
# 76          amsterdam  internacional    a1  muelle internacional oriente
# 77          amsterdam  internacional    a1  muelle internacional oriente
# 100         amsterdam  internacional    a1  muelle internacional oriente
# ...               ...            ...   ...                           ...
# 1168494  yuma arizona  internacional  rori  muelle internacional oriente
# 1168495  yuma arizona  internacional  rori  muelle internacional oriente
# 1168516  yuma arizona  internacional  rori  muelle internacional oriente
# 1168517  yuma arizona  internacional  rori  muelle internacional oriente
# 1168518  yuma arizona  internacional  rori  muelle internacional oriente
#
#         FECHA DIA                        AEROLÍNEA Tipo aerolínea  \
# 52         martes                          klm cia         legacy
# 53         martes                          klm cia         legacy
# 76         jueves                          klm cia         legacy
# 77         jueves                          klm cia         legacy
# 100       viernes                          klm cia         legacy
# ...           ...                              ...            ...
# 1168494    jueves       aerolinea de vuelo charter        charter
# 1168495    jueves       aerolinea de vuelo charter        charter
# 1168516   viernes  menzies aviation colombia s a s         legacy
# 1168517   viernes  menzies aviation colombia s a s         legacy
# 1168518   viernes  menzies aviation colombia s a s         legacy
#
#                         STD  Pasajeros saliendo  Hora entera  Semana  Mes  \
# 52      2022-01-04 16:05:00               124.0           15       1    1
# 53      2022-01-04 16:05:00               124.0           15       1    1
# 76      2022-01-06 16:05:00               194.0           16       1    1
# 77      2022-01-06 16:05:00               194.0           16       1    1
# 100     2022-01-14 16:05:00               217.0           16       2    1
# ...                     ...                 ...          ...     ...  ...
# 1168494 2022-06-02 09:15:00                39.0           15      22    6
# 1168495 2022-06-02 09:15:00                39.0           15      22    6
# 1168516 2022-10-07 08:00:00                34.0            9      40   10
# 1168517 2022-10-07 08:00:00                34.0            9      40   10
# 1168518 2022-10-07 08:00:00                34.0            9      40   10
#
#          Día   Año    STD_date  Pasajeros por Muelle y Hora  \
# 52         4  2022  2022-01-04                        124.0
# 53         4  2022  2022-01-04                        124.0
# 76         6  2022  2022-01-06                        370.0
# 77         6  2022  2022-01-06                        370.0
# 100       14  2022  2022-01-14                        217.0
# ...      ...   ...         ...                          ...
# 1168494    2  2022  2022-06-02                         39.0
# 1168495    2  2022  2022-06-02                         39.0
# 1168516    7  2022  2022-10-07                         34.0
# 1168517    7  2022  2022-10-07                         34.0
# 1168518    7  2022  2022-10-07                         34.0
#
#          Porcentaje pasajeros vuelo fecha_venta  hora_venta  \
# 52                         1.000000  2022-01-04        15.0
# 53                         1.000000  2022-01-04        16.0
# 76                         0.524324  2022-01-06        15.0
# 77                         0.524324  2022-01-06        16.0
# 100                        1.000000  2022-01-14        15.0
# ...                             ...         ...         ...
# 1168494                    1.000000  2022-06-02         8.0
# 1168495                    1.000000  2022-06-02         9.0
# 1168516                    1.000000  2022-10-07         6.0
# 1168517                    1.000000  2022-10-07         7.0
# 1168518                    1.000000  2022-10-07         8.0
#
#          transacciones_venta  valor_venta     timestamp_venta  time_difference
# 52                      92.0  107954452.5 2022-01-04 15:00:00         1.083333
# 53                      80.0   81808200.0 2022-01-04 16:00:00         0.083333
# 76                      56.0   56634740.0 2022-01-06 15:00:00         1.083333
# 77                      41.0   39942760.0 2022-01-06 16:00:00         0.083333
# 100                     55.0   42336460.0 2022-01-14 15:00:00         1.083333
# ...                      ...          ...                 ...              ...
# 1168494                 33.0   24296500.0 2022-06-02 08:00:00         1.250000
# 1168495                 33.0   18492500.0 2022-06-02 09:00:00         0.250000
# 1168516                 88.0   65587540.0 2022-10-07 06:00:00         2.000000
# 1168517                 69.0   52928880.0 2022-10-07 07:00:00         1.000000
# 1168518                 43.0   30413380.0 2022-10-07 08:00:00         0.000000
#
# [99759 rows x 23 columns]

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    hourly_sales_per_marca[marca] = df_marca_sales.groupby([
        "Destino",
        "Tipo de vuelo",
        "Sala",
        "Muelle",
        "AEROLÍNEA",
        "Tipo aerolínea",
        "STD",
        "Hora entera"
    ]).agg({
        "FECHA DIA": "min",
        "Pasajeros saliendo": "min",
        "Semana": "min",
        "Mes": "min",
        "Día": "min",
        "Año": "min",
        "Pasajeros por Muelle y Hora": "min",
        "Porcentaje pasajeros vuelo": "min",
        "valor_venta": "sum"
    }).reset_index(drop=False)

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    print(marca)
    for col in ["Pasajeros saliendo", "Pasajeros por Muelle y Hora", "Porcentaje pasajeros vuelo"]:
        univariate_utils.plot_column_distribution(
            df_marca_sales,
            col,
            (15,5),
            60
        )
# Out:
# marca 1
# marca 10
# marca 2
# marca 3
# marca 5
# marca 6
# marca 7
# marca 9

# %% [markdown]
# ### Asignacion de valor de venta y transacciones generado por pasajeros de un vuelo
# Se usa el porcentaje de pasajeros de ese vuelo sobre el total de pasajeros en una hora determinada para asignar el valor y transacciones de venta como el valor o transacciones de venta del muelle en esa hora multiplicado por el porcentaje de pasajeros correspondientes al vuelo en esa hora.
#
# **NOTA: Se generan valores encima de mil millones para la ganancia horaria de un muelle, y estos valores estan confirmados numericamente con test individuales y sobre el excel. Esto implica que pueden haber anomalias en el registro de estos valores en el Excel**
#
# Se hace clipping dados los valores extremos de Parte de valor_venta.

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    df_marca_sales["Parte de valor_venta"] = (
        df_marca_sales["valor_venta"]
        * df_marca_sales["Porcentaje pasajeros vuelo"]
    ).fillna(0.0)

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    print(marca)
    univariate_utils.plot_column_distribution(
        df_marca_sales,
        "Parte de valor_venta",
        (15,5),
        60
    )
# Out:
# marca 1
# marca 10
# marca 2
# marca 3
# marca 5
# marca 6
# marca 7
# marca 9

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    clip_data_by_iqr(df_marca_sales, "Parte de valor_venta", "top", 1.5)

# %%
for marca, df_marca_sales in hourly_sales_per_marca.items():
    print(marca)
    univariate_utils.plot_column_distribution(
        df_marca_sales,
        "Parte de valor_venta",
        (15,5),
        60
    )
# Out:
# marca 1
# marca 10
# marca 2
# marca 3
# marca 5
# marca 6
# marca 7
# marca 9

# %% [markdown]
# ### Saving results to dataframe

# %%
for marca, df_marca_sales in tqdm(hourly_sales_per_marca.items()):
    df_marca_sales.to_parquet(f"data/{marca}.parquet")
# Out:
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 30.18it/s]
